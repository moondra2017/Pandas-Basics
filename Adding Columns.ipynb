# %%
import pandas as pd

# %%
df = pd.read_csv("movie.csv").set_index('director_name').sort_index()

# %%
df.head(10)
# Out:
#                   color  num_critic_for_reviews  duration  \
# director_name
# A. Raven Cruz     Color                     3.0      97.0
# Aaron Hann        Color                    29.0      87.0
# Aaron Schneider   Color                   160.0     100.0
# Aaron Seltzer     Color                    99.0      85.0
# Abel Ferrara      Color                    48.0      99.0
# Adam Brooks       Color                   160.0     112.0
# Adam Carolla      Color                    14.0      98.0
# Adam Goldberg     Color                    22.0     111.0
# Adam Green        Color                   229.0      93.0
# Adam Jay Epstein  Color                    14.0      76.0
#
#                   director_facebook_likes  actor_3_facebook_likes  \
# director_name
# A. Raven Cruz                         0.0                    94.0
# Aaron Hann                            0.0                    94.0
# Aaron Schneider                      11.0                   970.0
# ...

# %%
df.columns
# Out:
# Index(['color', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 27

# %% [markdown]
# `Creating new Columns`
# -----------------

# %%
#using lists for column names

# %%
df.shape
# Out:
# (4916, 27)

# %%
df['new_column'] = "test"

# %%
df.columns
# Out:
# Index(['color', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'new_column'],
#       dtype='object')

# %%
df['new_column'].head()
# Out:
# director_name
# A. Raven Cruz      test
# Aaron Hann         test
# Aaron Schneider    test
# Aaron Seltzer      test
# Abel Ferrara       test
# Name: new_column, dtype: object

# %%
#Values can get overwritten

# %%
df['new_column2'] = df['duration'] + 5

# %%
df[['new_column2','duration']].head()
# Out:
#                  new_column2  duration
# director_name
# A. Raven Cruz          102.0      97.0
# Aaron Hann              92.0      87.0
# Aaron Schneider        105.0     100.0
# Aaron Seltzer           90.0      85.0
# Abel Ferrara           104.0      99.0

# %%
df.columns
# Out:
# Index(['color', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'new_column',
#        'new_column2'],
#       dtype='object')

# %%
#adding columns within dataframe

# %%
df.insert()

# %%
df.insert(0,"final_column", df['new_column2'] +3)

# %%
df.head()
# Out:
#                  final_column  color  num_critic_for_reviews  duration  \
# director_name
# A. Raven Cruz           105.0  Color                     3.0      97.0
# Aaron Hann               95.0  Color                    29.0      87.0
# Aaron Schneider         108.0  Color                   160.0     100.0
# Aaron Seltzer            93.0  Color                    99.0      85.0
# Abel Ferrara            107.0  Color                    48.0      99.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# director_name
# A. Raven Cruz                        0.0                    94.0
# Aaron Hann                           0.0                    94.0
# Aaron Schneider                     11.0                   970.0
# Aaron Seltzer                       64.0                   729.0
# Abel Ferrara                       220.0                   599.0
#
#                        actor_2_name  actor_1_facebook_likes       gross  \
# director_name
# ...
