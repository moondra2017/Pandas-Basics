# %%
import pandas as pd

# %%
df = pd.read_csv("movie.csv").set_index('director_name').sort_index()

# %%
df.head() #check out null values
# Out:
#                  color  num_critic_for_reviews  duration  \
# director_name
# A. Raven Cruz    Color                     3.0      97.0
# Aaron Hann       Color                    29.0      87.0
# Aaron Schneider  Color                   160.0     100.0
# Aaron Seltzer    Color                    99.0      85.0
# Abel Ferrara     Color                    48.0      99.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# director_name
# A. Raven Cruz                        0.0                    94.0
# Aaron Hann                           0.0                    94.0
# Aaron Schneider                     11.0                   970.0
# Aaron Seltzer                       64.0                   729.0
# Abel Ferrara                       220.0                   599.0
#
#                        actor_2_name  actor_1_facebook_likes       gross  \
# director_name
# A. Raven Cruz           Vanilla Ice                   639.0         NaN
# ...

# %%
df.tail() #null values in last few rows
# Out:
#                color  num_critic_for_reviews  duration  \
# director_name
# NaN            Color                    75.0      60.0
# NaN            Color                    11.0      22.0
# NaN            Color                    23.0      43.0
# NaN            Color                    11.0      58.0
# NaN            Color                    43.0      43.0
#
#                director_facebook_likes  actor_3_facebook_likes  \
# director_name
# NaN                                NaN                   833.0
# NaN                                NaN                     6.0
# NaN                                NaN                   576.0
# NaN                                NaN                   250.0
# NaN                                NaN                   319.0
#
#                    actor_2_name  actor_1_facebook_likes  gross  \
# director_name
# NaN                    Masi Oka                  1000.0    NaN
# NaN                   Ron Lynch                    59.0    NaN
# ...

# %%
df.dropna().tail() #all rows with any nulls values are  are dropped
# Out:
#                     color  num_critic_for_reviews  duration  \
# director_name
# Zack Snyder         Color                   287.0     110.0
# Zak Penn            Color                    60.0      94.0
# Zal Batmanglij      Color                   200.0     116.0
# Álex de la Iglesia  Color                    71.0     104.0
# Émile Gaudreault    Color                    67.0      92.0
#
#                     director_facebook_likes  actor_3_facebook_likes  \
# director_name
# Zack Snyder                             0.0                  1000.0
# Zak Penn                               87.0                    37.0
# Zal Batmanglij                        129.0                   782.0
# Álex de la Iglesia                    275.0                   102.0
# Émile Gaudreault                        9.0                    71.0
#
#                          actor_2_name  actor_1_facebook_likes       gross  \
# director_name
# ...

# %%
df.head()
# Out:
#                  color  num_critic_for_reviews  duration  \
# director_name
# A. Raven Cruz    Color                     3.0      97.0
# Aaron Hann       Color                    29.0      87.0
# Aaron Schneider  Color                   160.0     100.0
# Aaron Seltzer    Color                    99.0      85.0
# Abel Ferrara     Color                    48.0      99.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# director_name
# A. Raven Cruz                        0.0                    94.0
# Aaron Hann                           0.0                    94.0
# Aaron Schneider                     11.0                   970.0
# Aaron Seltzer                       64.0                   729.0
# Abel Ferrara                       220.0                   599.0
#
#                        actor_2_name  actor_1_facebook_likes       gross  \
# director_name
# A. Raven Cruz           Vanilla Ice                   639.0         NaN
# ...

# %%
df.dropna().head()
# Out:
#                  color  num_critic_for_reviews  duration  \
# director_name
# Aaron Schneider  Color                   160.0     100.0
# Aaron Seltzer    Color                    99.0      85.0
# Abel Ferrara     Color                    48.0      99.0
# Adam Goldberg    Color                    22.0     111.0
# Adam Marcus      Color                   112.0      91.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# director_name
# Aaron Schneider                     11.0                   970.0
# Aaron Seltzer                       64.0                   729.0
# Abel Ferrara                       220.0                   599.0
# Adam Goldberg                     1000.0                   127.0
# Adam Marcus                         18.0                   307.0
#
#                     actor_2_name  actor_1_facebook_likes       gross  \
# director_name
# Aaron Schneider    Robert Duvall                 13000.0   9176553.0
# ...

# %%
df.dropna().shape
# Out:
# (3655, 27)

# %%
df.shape
# Out:
# (4916, 27)

# %%
df.dropna()

# %%
df.dropna(how = "all").head()  #all columns must have null values
# Out:
#                  color  num_critic_for_reviews  duration  \
# director_name
# A. Raven Cruz    Color                     3.0      97.0
# Aaron Hann       Color                    29.0      87.0
# Aaron Schneider  Color                   160.0     100.0
# Aaron Seltzer    Color                    99.0      85.0
# Abel Ferrara     Color                    48.0      99.0
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# director_name
# A. Raven Cruz                        0.0                    94.0
# Aaron Hann                           0.0                    94.0
# Aaron Schneider                     11.0                   970.0
# Aaron Seltzer                       64.0                   729.0
# Abel Ferrara                       220.0                   599.0
#
#                        actor_2_name  actor_1_facebook_likes       gross  \
# director_name
# A. Raven Cruz           Vanilla Ice                   639.0         NaN
# ...

# %%
df.dropna(how = 'all').shape
# Out:
# (4916, 27)

# %%
df.shape
# Out:
# (4916, 27)

# %%
df.dropna(thresh = 24).shape #how many non-na values are required; 25 means, 25 columns must have good values
# Out:
# (4728, 27)

# %% [markdown]
# ### Column-wise instead of row-wise

# %%
len(df.columns)
# Out:
# 27

# %%
df.dropna(axis =1).columns
# Out:
# Index(['genres', 'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'movie_imdb_link', 'imdb_score', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### subsets

# %%
df.color.isnull()

# %%
df[df['color'].isnull()]

# %%
df.dropna(subset = ['color']).shape
# Out:
# (4897, 27)

# %%
df.shape
# Out:
# (4916, 27)

# %%
df.dropna(subset = ['color'])['color'].value_counts(dropna = False)
# Out:
# Color              4693
# Black and White     204
# Name: color, dtype: int64

# %%
df['color'].value_counts(dropna = False)
# Out:
# Color              4693
# Black and White     204
# NaN                  19
# Name: color, dtype: int64

# %% [markdown]
# ### Inplace = True

# %%
df.shape
# Out:
# (4916, 27)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (3655, 27)
